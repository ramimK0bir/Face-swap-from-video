# %%
# !git clone https://github.com/ramimK0bir/Face-swap-from-video.git
# %cd Face-swap-from-video
# !pip install -r requirements.txt

# %%
# Ensure you’re running it on a machine with a CUDA-enabled GPU.or skip this part
# !pip uninstall onnxruntime -y
# !pip install onnxruntime-gpu

# %%
# !python main.py --source testing/new.jpg --target testing/testing.mp4  --output ../output.mp4 --fps 30

# %%
# Go to file-folder tab and download your video(output.mp4)
# Make sure to disconnect and delete runtime after you're done.# Happy coding
